# %%
import random
from tqdm import tqdm
import time
start_time = time.time()


lista = []
for i in tqdm(range(1_000_000_000)):
    lista.append(random.randint(0,1001))

end_time = time.time()
print(f"Result calculated in {(end_time - start_time)//60} minutes and {(end_time - start_time)%60} seconds")
# Out:
#  93%|██████████████████████████████████████████████████████████▋    | 930954688/1000000000 [52:39<03:54, 294628.48it/s]
